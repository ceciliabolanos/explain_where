# %%
import json
output_path = f'/home/cbolanos/experiments/audioset/labels/distributions.json'
with open(output_path, 'r') as f:
   dist_dict = json.load(f)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def plot_logit_comparison(negative_logits, positive_logits, title="Distribution of Speech Logits"):
    """
    Plot the distribution of positive and negative logits with both histogram and kernel density estimation.
    
    Args:
        negative_logits (list or np.array): Array of negative class logit values
        positive_logits (list or np.array): Array of positive class logit values
        title (str): Title for the plot
    """
    # Create figure and axis
    fig, ax = plt.subplots(figsize=(12, 6))
    
    # Plot both distributions
    sns.histplot(data=negative_logits, bins=30, kde=True, color='red', alpha=0.4)
    sns.histplot(data=positive_logits, bins=30, kde=True, color='green', alpha=0.4)
    
    # Add title and labels
    plt.title(title, fontsize=14, pad=15)
    plt.xlabel('Logit Values', fontsize=12)
    plt.ylabel('Count', fontsize=12)
    
    # Add legend
    plt.legend()
    
    # Add statistics annotations
    stats_text = (
        f'Positive Stats:\n'
        f'Mean: {np.mean(positive_logits):.3f}\n'
        f'Median: {np.median(positive_logits):.3f}\n'
        f'Std: {np.std(positive_logits):.3f}\n\n'
        f'Negative Stats:\n'
        f'Mean: {np.mean(negative_logits):.3f}\n'
        f'Median: {np.median(negative_logits):.3f}\n'
        f'Std: {np.std(negative_logits):.3f}'
    )
    
    # Position the stats text box
    plt.text(0.95, 0.95, stats_text,
             transform=ax.transAxes,
             verticalalignment='top',
             horizontalalignment='right',
             bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    
    # Adjust layout to prevent text cutoff
    plt.tight_layout()
    
    return fig, ax

# %%
fig, ax = plot_logit_comparison(
    dist_dict['Speech_nc'],
    dist_dict['Speech_c'],
    "Distribution of Speech vs Non-Speech Logits"
)
plt.show()
# Out:
# /home/cbolanos/miniconda3/envs/tesis/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/cbolanos/miniconda3/envs/tesis/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plot_logit_comparison(
    dist_dict['Engine_nc'],
    dist_dict['Engine_c'],
    "Distribution of Engine vs Non-engine Logits"
)
plt.show()
# Out:
# /home/cbolanos/miniconda3/envs/tesis/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/cbolanos/miniconda3/envs/tesis/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plot_logit_comparison(
    dist_dict['Rail transport_nc'],
    dist_dict['Rail transport_c'],
    "Distribution of Rail transport Logits"
)
plt.show()
# Out:
# /home/cbolanos/miniconda3/envs/tesis/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/cbolanos/miniconda3/envs/tesis/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plot_logit_comparison(
    dist_dict['Boat, Water vehicle_nc'],
    dist_dict['Boat, Water vehicle_c'],
    "Distribution of Rail transport Logits"
)
plt.show()
# Out:
# /home/cbolanos/miniconda3/envs/tesis/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/cbolanos/miniconda3/envs/tesis/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
c_keys = [k for k in dist_dict.keys() if k.endswith('_c')]

# Sort them by length
sorted_c_keys = sorted(c_keys, key=len)

# Print each key with its length
for key in sorted_c_keys:
    print(f"{key}: {len(dist_dict[key])}")
# Out:
# Cat_c: 1513
# Car_c: 2016
# Tap_c: 171
# Dog_c: 2109
# Bus_c: 128
# Rub_c: 195
# Hum_c: 140
# Moo_c: 128
# Coo_c: 138
# Run_c: 173
# Pig_c: 238
# Caw_c: 142
# Owl_c: 137
# Yip_c: 245
# Ska_c: 5
# Bird_c: 1499
# Crow_c: 333
# Fart_c: 104
# Door_c: 1086
# Fowl_c: 1298
# Drip_c: 122
# Wood_c: 449
# Pour_c: 327
# Stir_c: 119
# Fire_c: 243
# Wind_c: 613
# Rain_c: 742
# Buzz_c: 117
# Bang_c: 107
# Purr_c: 91
# Bell_c: 673
# Ship_c: 150
# Boom_c: 94
# Drum_c: 136
# Duck_c: 294
# Chop_c: 135
# Meow_c: 313
# Whip_c: 114
# Whir_c: 57
# Sigh_c: 50
# Tick_c: 145
# Frog_c: 260
# Oink_c: 128
# Plop_c: 134
# Goat_c: 266
# Howl_c: 128
# Flap_c: 147
# Ping_c: 129
# Slam_c: 184
# Hiss_c: 211
# Funk_c: 15
# Gasp_c: 51
# Bark_c: 159
# Ding_c: 156
# Honk_c: 138
# Roll_c: 157
# Yell_c: 105
# Gush_c: 112
# Roar_c: 118
# Toot_c: 19
# Echo_c: 18
# Zing_c: 21
# Pant_c: 41
# Harp_c: 5
# Song_c: 20
# Jazz_c: 15
# Hoot_c: 17
# Music_c: 9440
# Cough_c: 173
# Alarm_c: 1774
# Tools_c: 905
# Train_c: 856
# Siren_c: 1018
# Truck_c: 1007
# Glass_c: 404
# Hands_c: 247
# Water_c: 1818
# Knock_c: 111
# Arrow_c: 355
# Clock_c: 447
# Horse_c: 1137
# Gears_c: 142
# Snort_c: 120
# Shout_c: 655
# Whoop_c: 127
# Crowd_c: 430
# Slosh_c: 144
# Noise_c: 295
# Cello_c: 13
# Quack_c: 135
# Spray_c: 139
# Opera_c: 18
# Pulse_c: 19
# Sheep_c: 371
# Boing_c: 86
# Mouse_c: 115
# Chant_c: 295
# Choir_c: 210
# Cluck_c: 221
# Croak_c: 73
# Bleat_c: 162
# Blues_c: 31
# Snake_c: 476
# Thunk_c: 88
# Ocean_c: 308
# Steam_c: 396
# Piano_c: 35
# Groan_c: 109
# Drill_c: 147
# Goose_c: 252
# Chime_c: 178
# Clang_c: 52
# Sniff_c: 24
# Grunt_c: 57
# Sonar_c: 75
# Strum_c: 38
# Radio_c: 34
# Flute_c: 14
# Disco_c: 17
# Crack_c: 61
# Tabla_c: 6
# Organ_c: 9
# Banjo_c: 8
# Sitar_c: 4
# Creak_c: 13
# Engine_c: 2774
# Animal_c: 4556
# Speech_c: 17307
# Hammer_c: 120
# Hiccup_c: 105
# Scrape_c: 110
# Giggle_c: 103
# Turkey_c: 313
# Gobble_c: 145
# Liquid_c: 1271
# Sawing_c: 109
# Guitar_c: 522
# Insect_c: 877
# Idling_c: 380
# Typing_c: 338
# Sizzle_c: 152
# Rumble_c: 100
# Camera_c: 319
# Stream_c: 225
# Bellow_c: 107
# Patter_c: 115
# Rattle_c: 140
# Squish_c: 88
# Mantra_c: 187
# Buzzer_c: 116
# Wheeze_c: 18
# Rustle_c: 175
# Crunch_c: 63
# Sneeze_c: 126
# Techno_c: 66
# Reggae_c: 9
# Squeak_c: 18
# Biting_c: 77
# Cymbal_c: 24
# Hi-hat_c: 11
# Squawk_c: 13
# Zither_c: 3
# Squeal_c: 18
# Grunge_c: 6
# Static_c: 3
# Maraca_c: 1
# Singing_c: 2064
# Snicker_c: 150
# Vehicle_c: 5554
# Rapping_c: 111
# Clatter_c: 170
# Dubstep_c: 123
# Shuffle_c: 114
# Whistle_c: 224
# Bow-wow_c: 332
# Country_c: 45
# Whimper_c: 126
# Thunder_c: 125
# Lullaby_c: 6
# Blender_c: 102
# Cowbell_c: 61
# Silence_c: 145
# Bicycle_c: 164
# Rimshot_c: 9
# Tearing_c: 66
# Humming_c: 77
# Crackle_c: 145
# Cap gun_c: 103
# Snoring_c: 145
# Printer_c: 129
# Scratch_c: 98
# Shatter_c: 65
# Cricket_c: 101
# Sanding_c: 19
# Sampler_c: 24
# Writing_c: 121
# Timpani_c: 7
# Boiling_c: 117
# Ukulele_c: 16
# Chatter_c: 14
# Trumpet_c: 9
# Foghorn_c: 33
# Pulleys_c: 9
# Laughter_c: 794
# Doorbell_c: 172
# Clapping_c: 133
# Clicking_c: 746
# Aircraft_c: 746
# Mosquito_c: 71
# Raindrop_c: 187
# Ringtone_c: 112
# Breaking_c: 134
# Splinter_c: 13
# Harmonic_c: 124
# Cheering_c: 236
# Chainsaw_c: 152
# Gurgling_c: 219
# Drum kit_c: 75
# Applause_c: 121
# Eruption_c: 146
# Scissors_c: 50
# Skidding_c: 66
# Yodeling_c: 86
# Babbling_c: 94
# Growling_c: 103
# Theremin_c: 2
# Bouncing_c: 31
# Flamenco_c: 18
# Gargling_c: 4
# Clarinet_c: 5
# Afrobeat_c: 3
# Trombone_c: 4
# Crushing_c: 11
# Steelpan_c: 4
# Mandolin_c: 4
# Sidetone_c: 3
# Bagpipes_c: 8
# Caterwaul_c: 256
# Explosion_c: 996
# Ding-dong_c: 111
# Car alarm_c: 99
# Telephone_c: 609
# Dial tone_c: 85
# Screaming_c: 131
# Clip-clop_c: 418
# Breathing_c: 493
# Sine wave_c: 247
# Pop music_c: 42
# Whistling_c: 105
# Bass drum_c: 33
# Fusillade_c: 91
# Pizzicato_c: 14
# Tick-tock_c: 181
# Waterfall_c: 167
# Air brake_c: 197
# A capella_c: 30
# Bluegrass_c: 14
# Fireworks_c: 244
# Throbbing_c: 71
# Orchestra_c: 22
# Vibration_c: 37
# Punk rock_c: 21
# Accordion_c: 9
# Mains hum_c: 30
# Saxophone_c: 4
# Harmonica_c: 6
# Drum roll_c: 5
# Cacophony_c: 4
# Sad music_c: 6
# Motorcycle_c: 173
# Fire alarm_c: 133
# Hair dryer_c: 74
# Burst, pop_c: 179
# Helicopter_c: 146
# Distortion_c: 64
# Power tool_c: 316
# Mechanisms_c: 1349
# Whispering_c: 108
# Typewriter_c: 108
# Battle cry_c: 98
# Television_c: 45
# Chirp tone_c: 35
# Train horn_c: 171
# Percussion_c: 295
# Snare drum_c: 26
# Jackhammer_c: 64
# Jet engine_c: 134
# Lawn mower_c: 142
# Wind chime_c: 73
# Skateboard_c: 103
# Rock music_c: 234
# Wail, moan_c: 26
# Toothbrush_c: 56
# Beatboxing_c: 10
# Soul music_c: 7
# Didgeridoo_c: 10
# Folk music_c: 5
# Pink noise_c: 12
# Tambourine_c: 4
# Wood block_c: 6
# Vibraphone_c: 3
# Beep, bleep_c: 145
# Swing music_c: 9
# Tuning fork_c: 21
# Jingle bell_c: 145
# Machine gun_c: 101
# Alarm clock_c: 113
# Bass guitar_c: 49
# Vocal music_c: 202
# Belly laugh_c: 102
# Church bell_c: 103
# Thump, thud_c: 201
# Tire squeal_c: 118
# Waves, surf_c: 139
# Firecracker_c: 117
# Dance music_c: 16
# Slap, smack_c: 113
# Synthesizer_c: 55
# Theme music_c: 14
# Busy signal_c: 38
# House music_c: 13
# Salsa music_c: 6
# Electronica_c: 25
# Harpsichord_c: 5
# Heavy metal_c: 35
# White noise_c: 9
# Funny music_c: 2
# French horn_c: 4
# Happy music_c: 6
# Scary music_c: 2
# Double bass_c: 4
# Angry music_c: 1
# Wild animals_c: 1900
# Male singing_c: 339
# Chink, clink_c: 231
# Effects unit_c: 213
# Chirp, tweet_c: 180
# Sound effect_c: 322
# Conversation_c: 191
# Sliding door_c: 221
# Heart murmur_c: 90
# Smash, crash_c: 154
# Pigeon, dove_c: 333
# Thunderstorm_c: 258
# Toilet flush_c: 132
# Drum machine_c: 19
# Bicycle bell_c: 33
# Trance music_c: 13
# Glockenspiel_c: 35
# Tender music_c: 12
# Gospel music_c: 31
# Singing bowl_c: 9
# Frying (food)_c: 154
# Hip hop music_c: 82
# Whimper (dog)_c: 278
# Fly, housefly_c: 315
# Steam whistle_c: 120
# Train whistle_c: 112
# Whack, thwack_c: 142
# Child singing_c: 256
# Ambient music_c: 18
# Neigh, whinny_c: 270
# Keys jangling_c: 134
# Chorus effect_c: 71
# Cash register_c: 84
# Music of Asia_c: 14
# Baby laughter_c: 100
# Ratchet, pawl_c: 157
# Filing (rasp)_c: 96
# Pump (liquid)_c: 178
# Rock and roll_c: 102
# Reverberation_c: 14
# New-age music_c: 7
# Wedding music_c: 3
# Drum and bass_c: 5
# Hammond organ_c: 3
# Tubular bells_c: 2
# Rail transport_c: 1678
# Jingle, tinkle_c: 126
# Violin, fiddle_c: 126
# Female singing_c: 340
# Car passing by_c: 234
# Vacuum cleaner_c: 119
# Clickety-clack_c: 117
# Artillery fire_c: 130
# Microwave oven_c: 135
# Stomach rumble_c: 27
# Mechanical fan_c: 111
# Exciting music_c: 18
# Sewing machine_c: 122
# Carnatic music_c: 3
# Jingle (music)_c: 7
# Electric piano_c: 7
# String section_c: 1
# Throat clearing_c: 68
# Rain on surface_c: 269
# Bee, wasp, etc._c: 299
# Cattle, bovinae_c: 341
# Reversing beeps_c: 170
# Crying, sobbing_c: 381
# Aircraft engine_c: 346
# Classical music_c: 42
# Walk, footsteps_c: 196
# Christian music_c: 53
# Engine starting_c: 249
# Shuffling cards_c: 63
# Electric guitar_c: 54
# Engine knocking_c: 119
# Rustling leaves_c: 34
# Coin (dropping)_c: 81
# Acoustic guitar_c: 45
# Finger snapping_c: 9
# Christmas music_c: 11
# Chopping (food)_c: 25
# Music of Africa_c: 8
# Field recording_c: 2
# Electronic music_c: 472
# Trickle, dribble_c: 143
# Rhythm and blues_c: 25
# Splash, splatter_c: 279
# Children playing_c: 103
# Chicken, rooster_c: 710
# Gunshot, gunfire_c: 674
# Air conditioning_c: 106
# Electronic tuner_c: 122
# Background music_c: 21
# Soundtrack music_c: 37
# Progressive rock_c: 11
# Chuckle, chortle_c: 114
# Video game music_c: 14
# Psychedelic rock_c: 5
# Brass instrument_c: 34
# Electronic organ_c: 2
# Emergency vehicle_c: 798
# Ambulance (siren)_c: 149
# Children shouting_c: 117
# Water tap, faucet_c: 184
# Basketball bounce_c: 121
# Zipper (clothing)_c: 83
# Computer keyboard_c: 110
# Mallet percussion_c: 89
# Synthetic singing_c: 198
# Independent music_c: 5
# Traditional music_c: 6
# Inside, small room_c: 1091
# Police car (siren)_c: 180
# Musical instrument_c: 1385
# Speech synthesizer_c: 185
# Whale vocalization_c: 34
# Music of Bollywood_c: 6
# Keyboard (musical)_c: 96
# Marimba, xylophone_c: 27
# Fill (with liquid)_c: 103
# Music for children_c: 25
# Boat, Water vehicle_c: 1347
# Civil defense siren_c: 121
# Rodents, rats, mice_c: 344
# Rattle (instrument)_c: 5
# Cutlery, silverware_c: 103
# Burping, eructation_c: 110
# Propeller, airscrew_c: 108
# Electric toothbrush_c: 53
# Environmental noise_c: 11
# Motor vehicle (road)_c: 2648
# Narration, monologue_c: 540
# Air horn, truck horn_c: 106
# Motorboat, speedboat_c: 283
# Baby cry, infant cry_c: 152
# Inside, public space_c: 56
# Crumpling, crinkling_c: 108
# Drawer open or close_c: 37
# Middle Eastern music_c: 5
# Chewing, mastication_c: 111
# Whoosh, swoosh, swish_c: 130
# Canidae, dogs, wolves_c: 401
# Rowboat, canoe, kayak_c: 162
# Race car, auto racing_c: 174
# Domestic animals, pets_c: 2830
# Electronic dance music_c: 8
# Sailboat, sailing ship_c: 187
# Telephone bell ringing_c: 107
# Dishes, pots, and pans_c: 161
# Train wheels squealing_c: 90
# Music of Latin America_c: 39
# Cupboard open or close_c: 16
# Wind noise (microphone)_c: 293
# Heart sounds, heartbeat_c: 245
# Bowed string instrument_c: 164
# Telephone dialing, DTMF_c: 102
# Railroad car, train wagon_c: 404
# Plucked string instrument_c: 607
# Male speech, man speaking_c: 612
# Outside, rural or natural_c: 511
# Outside, urban or manmade_c: 596
# Single-lens reflex camera_c: 231
# Sink (filling or washing)_c: 128
# Inside, large room or hall_c: 245
# Subway, metro, underground_c: 137
# Child speech, kid speaking_c: 315
# Steel guitar, slide guitar_c: 12
# Crowing, cock-a-doodle-doo_c: 149
# Tapping (guitar technique)_c: 3
# Smoke detector, smoke alarm_c: 89
# Bird flight, flapping wings_c: 51
# Traffic noise, roadway noise_c: 128
# Accelerating, revving, vroom_c: 385
# Heavy engine (low frequency)_c: 228
# Change ringing (campanology)_c: 97
# Roaring cats (lions, tigers)_c: 331
# Bathtub (filling or washing)_c: 124
# Light engine (high frequency)_c: 420
# Female speech, woman speaking_c: 331
# Medium engine (mid frequency)_c: 384
# Fixed-wing aircraft, airplane_c: 180
# Dental drill, dentist's drill_c: 16
# Ice cream truck, ice cream van_c: 61
# Vehicle horn, car horn, honking_c: 202
# Fire engine, fire truck (siren)_c: 156
# Electric shaver, electric razor_c: 126
# Power windows, electric windows_c: 55
# Scratching (performance technique)_c: 15
# Hubbub, speech noise, speech babble_c: 159
# Wind instrument, woodwind instrument_c: 36
# Bird vocalization, bird call, bird song_c: 433
# Livestock, farm animals, working animals_c: 1871
